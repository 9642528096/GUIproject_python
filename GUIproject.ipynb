# %%
from tkinter import*
root=Tk()
root.geometry("500x500")
f0=Frame(root,bg="light blue")
f1=Frame(root,bg="light yellow")
f2=Frame(root,bg="red")
f3=Frame(root,bg="pink")
f4=Frame(root,bg="blue")
f5=Frame(root,bg="blue")
f6=Frame(root,bg="yellow")
f7=Frame(root,bg="blue")
f8=Frame(root,bg="blue")
f9=Frame(root,bg="blue")
def swap(frame):
 frame.tkraise()
for frame in (f0,f1,f2,f2,f3,f4,f5,f6,f7,f8,f9):
 frame.grid(row=0,column=0,sticky="news")
def calculate():
 global weight
 global height
 weight=float(weight.get())
 height=float(height.get())
 bmi=float((weight)/(height**2))
 bmi_num.set("Your BMI IS % .2f" % bmi)
 if bmi<18.5:
       bmi_text.set("You are underweighted")
 if 18.5<=bmi<25:
        bmi_text.set("you are normal")
 if 25<= bmi <30:
         bmi_text.set("your are over")
 if 30<=bmi>30:
     bmi_text.set("you are obese")
Label(f1,text="WELCOME TO \nHEALTH TRACKER AND RECOMMONDER SYSTEM",bg="light blue",font="verdana 10 bold italic").place(x=20,y=50)
Button(f1,text="ENTER",command=lambda:swap(f2),fg="green").place(x=180,y=200)


Label(f2,text="SELECT YOUR PROBLEM",font="verdana 20 bold italic",bg="blue").pack()
Button(f2,text="BMI",command=lambda:swap(f3)).place(x=5,y=100)
Button(f2,text="FEVER",command=lambda:swap(f4)).place(x=5,y=200)
Button(f2,text="BP",command=lambda:swap(f5)).place(x=105,y=100)
Button(f2,text="COVID",command=lambda:swap(f6)).place(x=105,y=200)
Button(f2,text="MALARIA",command=lambda:swap(f7)).place(x=210,y=100)
Button(f2,text="JAUNDICE",command=lambda:swap(f8)).place(x=210,y=200)
Button(f2,text="DIABETES",command=lambda:swap(f9)).place(x=300,y=100)
Button(f2,text="back",command=lambda:swap(f1)).place(x=10,y=300)
Label(f3,text="BMI CALCULATOR",font="verdana 20 bold italic",bg="blue").pack()
Label(f3,text="ENTER YOUR WEIGHT IN KILOGRAMS").pack()
weight=StringVar()
Entry(f3,textvariable=weight).pack()
Label(f3,text="ENTER YOUR HEIGHT IN METERS").pack()
height=StringVar()
Entry(f3,textvariable=height).pack()
buttontext=StringVar()
Button(f3,textvariable=buttontext,command=calculate,).pack()
buttontext.set("Calculate")
bmi_num=StringVar()
Label(f3,textvariable=bmi_num).pack()
bmi_text=StringVar()
Label(f3,textvariable=bmi_text).pack()
Button(f3,text="back",command=lambda:swap(f2),bg="red").pack()
Label(f4,text="FEVER",font="verdana 20 bold italic",bg="orange").pack()
Label(f4,text="Normal body temperature is about 98.6 degrees Fahrenheit\nor 37degrees celsius. Normal temperature varies.").pack()
Label(f4,text="In adults a fever is considered to be a temperature\n of 100.4degree fahrenheit.\nThis can be cured at home by taking below medicines\n").pack()
Label(f4,text="1.Dolo 650 \n 2.acepaminophen\n 3.paracetmol\n 4.And drinkglucose\n5.Take rest",fg="green").pack()
Label(f4,text="if fever above 102 degrees consult a hospital",fg="red").pack()
Button(f4,text="back",command=lambda:swap(f2),bg="red").pack()
Label(f5,text="BLOOD PRESSURE",font="verdana 20 bold italic",bg="orange").pack()
Label(f5,text="1.if BP below 120/80-normal condition").pack(pady=10,padx=10)
Label(f5,text="2.if BP above 125/85-Elevated").pack(pady=10,padx=10)
Label(f5,text="3.if BP above 130/90-Hypertension").pack(pady=10,padx=10)
Label(f5,text="4.if BP above 180/120-Hypertensive crisis").pack(pady=10,padx=10)
Label(f5,text="FOLLOW THIS PRECAUTIONS TO CONTROL BP:",fg="red").pack()
Label(f5,text="1.Exercise regularly\n2.Eat a healthy diet\n3.Limit amount ofalcohol\n4.reduce stress").pack()
Button(f5,text="back",command=lambda:swap(f2),bg="red").pack()
Label(f6,text="COVID-19",font="bold",fg="blue").pack(pady=10,padx=10)
Label(f6,text="***N0 VACCINE YET***",fg="red").pack()
Label(f6,text="CORONA SYMPTOMS:",fg="red").pack()
Label(f6,text="1.Dry cough\n2.Fever\n3.Cold\n4.Difficultyin breathing").pack()
Label(f6,text="CORONA PREVENTION:",fg="red").pack()
Label(f6,text="1.Wear Mask\n2.Wash Hands regularly\n3.Social Distance").pack()
Label(f6,text="CORONA PRECAUTIONS:",fg="red").pack()
Label(f6,text="1.Healthy Diet\n2.Do Exercise").pack()
Button(f6,text="back",command=lambda:swap(f2),fg="red").pack()
Label(f7,text="MALARIA",fg="orange",font="bold").pack(pady=10,padx=10)
Label(f7,text="MALARIA SYMPTOMS:",fg="red").pack()
Label(f7,text="1.pain in muscles\n2.Fever\n3.Sweating nighttimes\n4.Diarrhoea\n5.Headache").pack()
Label(f7,text="MALARIA PREVENTION:",fg="red").pack()
Label(f7,text="1.Use insect reppellent\n2.Use mosquito net\n3.Sprayinsecticide").pack()
Label(f7,text="MALARIA MEDICATION:",fg="red").pack()
Label(f7,text="1.Chlroquine\n2.Atovoquene").pack()
Button(f7,text="back",command=lambda:swap(f2),fg="red").pack()
Label(f9,text="DAIBETES",fg="red",font="bold").pack(pady=10,padx=10)
Label(f9,text="SOME SYMPTOMS ARE:",fg="red").pack()
Label(f9,text="1.Excessive hunger\n2.Excessive thirst\n3.Weight gain orloss\n4.Frequent urination\n5.Blurred vision\n6.Poor wound healing").pack()
Label(f9,text="FOLLOW THIS PRECAUTIONS TO CONTROL DIABETES:",fg="red").pack()
Label(f9,text="1.take food rich in fiber\n2.Control your weight\n3.Keep your heart healthy\n",fg="green").pack()
Label(f9,text="MEDICATION:",fg="red").pack()
Label(f9,text="1.Metformin\n2.Sulfonylureas\n3.meglitinides").pack()
Button(f9,text="back",command=lambda:swap(f2),fg="red").pack()
Label(f8,text="JAUNDICE",fg="orange",font="bold").pack(pady=10,padx=10)
Label(f8,text="JAUNDICE SYMPTOMS:",fg="red").pack()
Label(f8,text="1.Fever\n2.Flu-like symptoms\n3.Change in skin color\n4.Abdominalpain").pack()
Label(f8,text="JAUNDICE PREVENTION:",fg="red").pack()
Label(f8,text="1.Avoid hepatatis infection\n2.Manage cholestral\n3.Maintain healthyweight").pack()
Label(f8,text="JAUNDICE MEDICATION:",fg="red").pack()
Label(f8,text="1.Dialysis for kidney damage\n2.Antibiotics for infection\n3.Seriouscondition consult doctor").pack()
Button(f8,text="back",command=lambda:swap(f2),fg="red").pack()
f1.tkraise()



root.mainloop()
